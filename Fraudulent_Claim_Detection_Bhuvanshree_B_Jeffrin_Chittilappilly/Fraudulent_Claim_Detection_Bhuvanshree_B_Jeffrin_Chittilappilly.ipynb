# %% [markdown]
# ## **Fraudulent Claim Detection**

# %% [markdown]
# ## Problem Statement
# Global Insure, a leading insurance company, processes thousands of claims annually. However, a significant percentage of these claims turn out to be fraudulent, resulting in considerable financial losses. The company’s current process for identifying fraudulent claims involves manual inspections, which is time-consuming and inefficient. Fraudulent claims are often detected too late in the process, after the company has already paid out significant amounts. Global Insure wants to improve its fraud detection process using data-driven insights to classify claims as fraudulent or legitimate early in the approval process. This would minimise financial losses and optimise the overall claims handling process.
#
# ## Business Objective
# Global Insure wants to build a model to classify insurance claims as either fraudulent or legitimate based on historical claim details and customer profiles. By using features like claim amounts, customer profiles and claim types, the company aims to predict which claims are likely to be fraudulent before they are approved.
#
#
# Based on this assignment, you have to answer the following questions:<br>
#
# ● How can we analyse historical claim data to detect patterns that indicate fraudulent claims?<br>
# ● Which features are most predictive of fraudulent behaviour?<br>
# ● Can we predict the likelihood of fraud for an incoming claim, based on past data?<br>
# ● What insights can be drawn from the model that can help in improving the fraud detection process?<br>

# %% [markdown]
# ## Assignment Tasks
# You need to perform the following steps for successfully completing this assignment:
# 1. Data Preparation
# 2. Data Cleaning
# 3. Train Validation Split 70-30
# 4. EDA on Training Data
# 5. EDA on Validation Data (optional)
# 6. Feature Engineering
# 7. Model Building
# 8. Predicting and Model Evaluation

# %% [markdown]
# ## Data Dictionary
# The insurance claims data has 40 Columns and 1000 Rows. Following data dictionary provides the description for each column present in dataset:<br>
#
# <table>
#   <thead>
#     <tr>
#       <th>Column Name</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>months_as_customer</td>
#       <td>Represents the duration in months that a customer has been associated with the insurance company.</td>
#     </tr>
#     <tr>
#       <td>age</td>
#       <td>Represents the age of the insured person.</td>
#     </tr>
#     <tr>
#       <td>policy_number</td>
#       <td>Represents a unique identifier for each insurance policy.</td>
#     </tr>
#     <tr>
#       <td>policy_bind_date</td>
#       <td>Represents the date when the insurance policy was initiated.</td>
#     </tr>
#     <tr>
#       <td>policy_state</td>
#       <td>Represents the state where the insurance policy is applicable.</td>
#     </tr>
#     <tr>
#       <td>policy_csl</td>
#       <td>Represents the combined single limit for the insurance policy.</td>
#     </tr>
#     <tr>
#       <td>policy_deductable</td>
#       <td>Represents the amount that the insured person needs to pay before the insurance coverage kicks in.</td>
#     </tr>
#     <tr>
#       <td>policy_annual_premium</td>
#       <td>Represents the yearly cost of the insurance policy.</td>
#     </tr>
#     <tr>
#       <td>umbrella_limit</td>
#       <td>Represents an additional layer of liability coverage provided beyond the limits of the primary insurance policy.</td>
#     </tr>
#     <tr>
#       <td>insured_zip</td>
#       <td>Represents the zip code of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_sex</td>
#       <td>Represents the gender of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_education_level</td>
#       <td>Represents the highest educational qualification of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_occupation</td>
#       <td>Represents the profession or job of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_hobbies</td>
#       <td>Represents the hobbies or leisure activities of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_relationship</td>
#       <td>Represents the relationship of the insured person to the policyholder.</td>
#     </tr>
#     <tr>
#       <td>capital-gains</td>
#       <td>Represents the profit earned from the sale of assets such as stocks, bonds, or real estate.</td>
#     </tr>
#     <tr>
#       <td>capital-loss</td>
#       <td>Represents the loss incurred from the sale of assets such as stocks, bonds, or real estate.</td>
#     </tr>
#     <tr>
#       <td>incident_date</td>
#       <td>Represents the date when the incident or accident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_type</td>
#       <td>Represents the category or type of incident that led to the claim.</td>
#     </tr>
#     <tr>
#       <td>collision_type</td>
#       <td>Represents the type of collision that occurred in an accident.</td>
#     </tr>
#     <tr>
#       <td>incident_severity</td>
#       <td>Represents the extent of damage or injury caused by the incident.</td>
#     </tr>
#     <tr>
#       <td>authorities_contacted</td>
#       <td>Represents the authorities or agencies that were contacted after the incident.</td>
#     </tr>
#     <tr>
#       <td>incident_state</td>
#       <td>Represents the state where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_city</td>
#       <td>Represents the city where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_location</td>
#       <td>Represents the specific location or address where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_hour_of_the_day</td>
#       <td>Represents the hour of the day when the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>number_of_vehicles_involved</td>
#       <td>Represents the total number of vehicles involved in the incident.</td>
#     </tr>
#     <tr>
#       <td>property_damage</td>
#       <td>Represents whether there was any damage to property in the incident.</td>
#     </tr>
#     <tr>
#       <td>bodily_injuries</td>
#       <td>Represents the number of bodily injuries resulting from the incident.</td>
#     </tr>
#     <tr>
#       <td>witnesses</td>
#       <td>Represents the number of witnesses present at the scene of the incident.</td>
#     </tr>
#     <tr>
#       <td>police_report_available</td>
#       <td>Represents whether a police report is available for the incident.</td>
#     </tr>
#     <tr>
#       <td>total_claim_amount</td>
#       <td>Represents the total amount claimed by the insured person for the incident.</td>
#     </tr>
#     <tr>
#       <td>injury_claim</td>
#       <td>Represents the amount claimed for injuries sustained in the incident.</td>
#     </tr>
#     <tr>
#       <td>property_claim</td>
#       <td>Represents the amount claimed for property damage in the incident.</td>
#     </tr>
#     <tr>
#       <td>vehicle_claim</td>
#       <td>Represents the amount claimed for vehicle damage in the incident.</td>
#     </tr>
#     <tr>
#       <td>auto_make</td>
#       <td>Represents the manufacturer of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>auto_model</td>
#       <td>Represents the specific model of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>auto_year</td>
#       <td>Represents the year of manufacture of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>fraud_reported</td>
#       <td>Represents whether the claim was reported as fraudulent or not.</td>
#     </tr>
#     <tr>
#       <td>_c39</td>
#       <td>Represents an unknown or unspecified variable.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **1. Data Preparation**
# In this step, read the dataset provided in CSV format and look at basic statistics of the data, including preview of data, dimension of data, column descriptions and data types.

# %% [markdown]
# ### **1.0 Import Libraries**

# %%
# Supress unnecessary warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### **1.1 Load the Data**

# %%
# Load the dataset
df = pd.read_csv('insurance_claims.csv')

# %%
# Check at the first few entries
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0       466132  ...                     YES              71610         6510
# 1       468176  ...                       ?               5070          780
# 2       430632  ...                      NO              34650         7700
# 3       608117  ...                      NO              63400         6340
# 4       610706  ...                      NO               6500         1300
#
#   property_claim vehicle_claim  auto_make  auto_model auto_year  \
# 0          13020         52080       Saab         92x      2004
# 1            780          3510   Mercedes        E400      2007
# 2           3850         23100      Dodge         RAM      2007
# 3           6340         50720  Chevrolet       Tahoe      2014
# 4            650          4550     Accura         RSX      2009
#
#   fraud_reported _c39
# 0              Y  NaN
# 1              Y  NaN
# 2              N  NaN
# 3              Y  NaN
# 4              N  NaN
#
# [5 rows x 40 columns]

# %%
# Inspect the shape of the dataset
df.shape
# Out:
# (1000, 40)

# %%
# Inspect the features in the dataset
df.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# min               433.330000   -1.000000e+06  430104.000000       0.000000
# 25%              1089.607500    0.000000e+00  448404.500000       0.000000
# 50%              1257.200000    0.000000e+00  466445.500000       0.000000
# 75%              1415.695000    0.000000e+00  603251.000000   51025.000000
# max              2047.590000    1.000000e+07  620962.000000  100500.000000
#
#         capital-loss  incident_hour_of_the_day  number_of_vehicles_involved  \
# count    1000.000000               1000.000000                   1000.00000
# mean   -26793.700000                 11.644000                      1.83900
# std     28104.096686                  6.951373                      1.01888
# min   -111100.000000                  0.000000                      1.00000
# 25%    -51500.000000                  6.000000                      1.00000
# 50%    -23250.000000                 12.000000                      1.00000
# 75%         0.000000                 17.000000                      3.00000
# max         0.000000                 23.000000                      4.00000
#
#        bodily_injuries    witnesses  total_claim_amount  injury_claim  \
# count      1000.000000  1000.000000          1000.00000   1000.000000
# mean          0.992000     1.487000         52761.94000   7433.420000
# std           0.820127     1.111335         26401.53319   4880.951853
# min           0.000000     0.000000           100.00000      0.000000
# 25%           0.000000     1.000000         41812.50000   4295.000000
# 50%           1.000000     1.000000         58055.00000   6775.000000
# 75%           2.000000     2.000000         70592.50000  11305.000000
# max           2.000000     3.000000        114920.00000  21450.000000
#
#        property_claim  vehicle_claim    auto_year  _c39
# count     1000.000000    1000.000000  1000.000000   0.0
# mean      7399.570000   37928.950000  2005.103000   NaN
# std       4824.726179   18886.252893     6.015861   NaN
# min          0.000000      70.000000  1995.000000   NaN
# 25%       4445.000000   30292.500000  2000.000000   NaN
# 50%       6750.000000   42100.000000  2005.000000   NaN
# 75%      10885.000000   50822.500000  2010.000000   NaN
# max      23670.000000   79560.000000  2015.000000   NaN

# %% [markdown]
# ## **2. Data Cleaning** <font color = red>[10 marks]</font>

# %% [markdown]
# ### **2.1 Handle null values** <font color = red>[2 marks]</font>

# %% [markdown]
# #### **2.1.1** Examine the columns to determine if any value or column needs to be treated <font color="red">[1 Mark]</font>

# %%
# Check the number of missing values in each column
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted            91
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# number_of_vehicles_involved       0
# property_damage                   0
# bodily_injuries                   0
# witnesses                         0
# police_report_available           0
# total_claim_amount                0
# injury_claim                      0
# property_claim                    0
# vehicle_claim                     0
# auto_make                         0
# auto_model                        0
# auto_year                         0
# fraud_reported                    0
# _c39                           1000
# dtype: int64

# %% [markdown]
# #### **2.1.2** Handle rows containing null values <font color="red">[1 Mark]</font>

# %%
# Handle the rows containing null values
df['authorities_contacted'] = df['authorities_contacted'].fillna('Unknown')

# %%
df['authorities_contacted'].value_counts()
# Out:
# authorities_contacted
# Police       292
# Fire         223
# Other        198
# Ambulance    196
# Unknown       91
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# number_of_vehicles_involved       0
# property_damage                   0
# bodily_injuries                   0
# witnesses                         0
# police_report_available           0
# total_claim_amount                0
# injury_claim                      0
# property_claim                    0
# vehicle_claim                     0
# auto_make                         0
# auto_model                        0
# auto_year                         0
# fraud_reported                    0
# _c39                           1000
# dtype: int64

# %% [markdown]
# ### **2.2 Identify and handle redundant values and columns** <font color = red>[5 marks]</font>

# %% [markdown]
# #### **2.2.1** Examine the columns to determine if any value or column needs to be treated <font color="red">[2 Mark]</font>

# %%
# Write code to display all the columns with their unique values and counts and check for redundant values
for col in df.columns:
    print(f"column : {col}")
    print(f"unique_values : {df[col].value_counts()}")
# Out:
# column : months_as_customer
# unique_values : months_as_customer
# 194    8
# 128    7
# 254    7
# 140    7
# 210    7
#       ..
# 390    1
# 411    1
# 453    1
# 448    1
# 17     1
# Name: count, Length: 391, dtype: int64
# column : age
# unique_values : age
# 43    49
# 39    48
# 41    45
# 34    44
# 38    42
# 30    42
# 31    42
# 37    41
# 33    39
# 40    38
# 32    38
# 29    35
# 46    33
# 42    32
# 35    32
# 36    32
# 44    32
# 28    30
# 26    26
# 45    26
# 48    25
# 47    24
# 27    24
# 57    16
# 25    14
# 55    14
# 49    14
# 53    13
# 50    13
# 24    10
# 54    10
# 61    10
# 51     9
# 60     9
# 58     8
# 56     8
# 23     7
# 21     6
# 59     5
# 62     4
# 52     4
# 64     2
# 63     2
# 19     1
# 20     1
# 22     1
# Name: count, dtype: int64
# column : policy_number
# unique_values : policy_number
# 521585    1
# 687755    1
# 674485    1
# 223404    1
# 991480    1
#          ..
# 563878    1
# 620855    1
# 583169    1
# 337677    1
# 556080    1
# Name: count, Length: 1000, dtype: int64
# column : policy_bind_date
# unique_values : policy_bind_date
# 2006-01-01    3
# 1992-04-28    3
# 1992-08-05    3
# 1991-12-14    2
# 2004-08-09    2
#              ..
# 2014-06-03    1
# 1998-12-12    1
# 1999-02-18    1
# 1997-10-30    1
# 1996-11-11    1
# Name: count, Length: 951, dtype: int64
# column : policy_state
# unique_values : policy_state
# OH    352
# IL    338
# IN    310
# Name: count, dtype: int64
# column : policy_csl
# unique_values : policy_csl
# 250/500     351
# 100/300     349
# 500/1000    300
# Name: count, dtype: int64
# column : policy_deductable
# unique_values : policy_deductable
# 1000    351
# 500     342
# 2000    307
# Name: count, dtype: int64
# column : policy_annual_premium
# unique_values : policy_annual_premium
# 1558.29    2
# 1215.36    2
# 1362.87    2
# 1073.83    2
# 1389.13    2
#           ..
# 1085.03    1
# 1437.33    1
# 988.29     1
# 1238.89    1
# 766.19     1
# Name: count, Length: 991, dtype: int64
# column : umbrella_limit
# unique_values : umbrella_limit
#  0           798
#  6000000      57
#  5000000      46
#  4000000      39
#  7000000      29
#  3000000      12
#  8000000       8
#  9000000       5
#  2000000       3
#  10000000      2
# -1000000       1
# Name: count, dtype: int64
# column : insured_zip
# unique_values : insured_zip
# 477695    2
# 469429    2
# 446895    2
# 431202    2
# 456602    2
#          ..
# 476303    1
# 450339    1
# 476502    1
# 600561    1
# 612260    1
# Name: count, Length: 995, dtype: int64
# column : insured_sex
# unique_values : insured_sex
# FEMALE    537
# MALE      463
# Name: count, dtype: int64
# column : insured_education_level
# unique_values : insured_education_level
# JD             161
# High School    160
# Associate      145
# MD             144
# Masters        143
# PhD            125
# College        122
# Name: count, dtype: int64
# column : insured_occupation
# unique_values : insured_occupation
# machine-op-inspct    93
# prof-specialty       85
# tech-support         78
# sales                76
# exec-managerial      76
# craft-repair         74
# transport-moving     72
# other-service        71
# priv-house-serv      71
# armed-forces         69
# adm-clerical         65
# protective-serv      63
# handlers-cleaners    54
# farming-fishing      53
# Name: count, dtype: int64
# column : insured_hobbies
# unique_values : insured_hobbies
# reading           64
# exercise          57
# paintball         57
# bungie-jumping    56
# movies            55
# golf              55
# camping           55
# kayaking          54
# yachting          53
# hiking            52
# video-games       50
# skydiving         49
# base-jumping      49
# board-games       48
# polo              47
# chess             46
# dancing           43
# sleeping          41
# cross-fit         35
# basketball        34
# Name: count, dtype: int64
# column : insured_relationship
# unique_values : insured_relationship
# own-child         183
# other-relative    177
# not-in-family     174
# husband           170
# wife              155
# unmarried         141
# Name: count, dtype: int64
# column : capital-gains
# unique_values : capital-gains
# 0        508
# 46300      5
# 51500      4
# 68500      4
# 55600      3
#         ...
# 36700      1
# 54900      1
# 69200      1
# 48800      1
# 50300      1
# Name: count, Length: 338, dtype: int64
# column : capital-loss
# unique_values : capital-loss
#  0        475
# -31700      5
# -53700      5
# -50300      5
# -45300      4
#          ...
# -12100      1
# -17000      1
# -72900      1
# -19700      1
# -82100      1
# Name: count, Length: 354, dtype: int64
# column : incident_date
# unique_values : incident_date
# 2015-02-02    28
# 2015-02-17    26
# 2015-01-07    25
# 2015-01-10    24
# 2015-02-04    24
# 2015-01-24    24
# 2015-01-19    23
# 2015-01-08    22
# 2015-01-13    21
# 2015-01-30    21
# 2015-02-12    20
# 2015-02-22    20
# 2015-01-31    20
# 2015-02-06    20
# 2015-02-21    19
# 2015-01-01    19
# 2015-02-23    19
# 2015-01-12    19
# 2015-01-14    19
# 2015-01-21    19
# 2015-01-03    18
# 2015-02-14    18
# 2015-02-01    18
# 2015-02-28    18
# 2015-01-20    18
# 2015-01-18    18
# 2015-02-25    18
# 2015-01-06    17
# 2015-01-09    17
# 2015-02-08    17
# 2015-02-24    17
# 2015-02-26    17
# 2015-02-13    16
# 2015-02-15    16
# 2015-02-16    16
# 2015-02-05    16
# 2015-01-16    16
# 2015-01-17    15
# 2015-02-18    15
# 2015-01-28    15
# 2015-01-15    15
# 2015-01-22    14
# 2015-02-20    14
# 2015-02-27    14
# 2015-01-23    13
# 2015-02-03    13
# 2015-01-27    13
# 2015-02-09    13
# 2015-01-04    12
# 2015-03-01    12
# 2015-01-26    11
# 2015-01-29    11
# 2015-01-02    11
# 2015-02-19    10
# 2015-02-11    10
# 2015-02-10    10
# 2015-02-07    10
# 2015-01-25    10
# 2015-01-11     9
# 2015-01-05     7
# Name: count, dtype: int64
# column : incident_type
# unique_values : incident_type
# Multi-vehicle Collision     419
# Single Vehicle Collision    403
# Vehicle Theft                94
# Parked Car                   84
# Name: count, dtype: int64
# column : collision_type
# unique_values : collision_type
# Rear Collision     292
# Side Collision     276
# Front Collision    254
# ?                  178
# Name: count, dtype: int64
# column : incident_severity
# unique_values : incident_severity
# Minor Damage      354
# Total Loss        280
# Major Damage      276
# Trivial Damage     90
# Name: count, dtype: int64
# column : authorities_contacted
# unique_values : authorities_contacted
# Police       292
# Fire         223
# Other        198
# Ambulance    196
# Unknown       91
# Name: count, dtype: int64
# column : incident_state
# unique_values : incident_state
# NY    262
# SC    248
# WV    217
# VA    110
# NC    110
# PA     30
# OH     23
# Name: count, dtype: int64
# column : incident_city
# unique_values : incident_city
# Springfield    157
# Arlington      152
# Columbus       149
# Northbend      145
# Hillsdale      141
# Riverwood      134
# Northbrook     122
# Name: count, dtype: int64
# column : incident_location
# unique_values : incident_location
# 9935 4th Drive         1
# 4214 MLK Ridge         1
# 8548 Cherokee Ridge    1
# 2352 MLK Drive         1
# 9734 2nd Ridge         1
#                       ..
# 6770 1st St            1
# 4119 Texas St          1
# 4347 2nd Ridge         1
# 1091 1st Drive         1
# 1416 Cherokee Ridge    1
# Name: count, Length: 1000, dtype: int64
# column : incident_hour_of_the_day
# unique_values : incident_hour_of_the_day
# 17    54
# 3     53
# 0     52
# 23    51
# 16    49
# 13    46
# 10    46
# 4     46
# 6     44
# 9     43
# 14    43
# 21    42
# 18    41
# 12    40
# 19    40
# 7     40
# 15    39
# 22    38
# 8     36
# 20    34
# 5     33
# 2     31
# 11    30
# 1     29
# Name: count, dtype: int64
# column : number_of_vehicles_involved
# unique_values : number_of_vehicles_involved
# 1    581
# 3    358
# 4     31
# 2     30
# Name: count, dtype: int64
# column : property_damage
# unique_values : property_damage
# ?      360
# NO     338
# YES    302
# Name: count, dtype: int64
# column : bodily_injuries
# unique_values : bodily_injuries
# 0    340
# 2    332
# 1    328
# Name: count, dtype: int64
# column : witnesses
# unique_values : witnesses
# 1    258
# 2    250
# 0    249
# 3    243
# Name: count, dtype: int64
# column : police_report_available
# unique_values : police_report_available
# ?      343
# NO     343
# YES    314
# Name: count, dtype: int64
# column : total_claim_amount
# unique_values : total_claim_amount
# 59400    5
# 2640     4
# 70400    4
# 4320     4
# 44200    4
#         ..
# 65250    1
# 87100    1
# 6240     1
# 66600    1
# 67500    1
# Name: count, Length: 763, dtype: int64
# column : injury_claim
# unique_values : injury_claim
# 0        25
# 640       7
# 480       7
# 660       5
# 580       5
#          ..
# 14840     1
# 6580      1
# 11820     1
# 16650     1
# 7500      1
# Name: count, Length: 638, dtype: int64
# column : property_claim
# unique_values : property_claim
# 0        19
# 860       6
# 480       5
# 660       5
# 10000     5
#          ..
# 3590      1
# 6480      1
# 4580      1
# 4920      1
# 7500      1
# Name: count, Length: 626, dtype: int64
# column : vehicle_claim
# unique_values : vehicle_claim
# 5040     7
# 3360     6
# 52080    5
# 4720     5
# 3600     5
#         ..
# 43360    1
# 25130    1
# 38940    1
# 47430    1
# 52500    1
# Name: count, Length: 726, dtype: int64
# column : auto_make
# unique_values : auto_make
# Saab          80
# Dodge         80
# Suburu        80
# Nissan        78
# Chevrolet     76
# Ford          72
# BMW           72
# Toyota        70
# Audi          69
# Accura        68
# Volkswagen    68
# Jeep          67
# Mercedes      65
# Honda         55
# Name: count, dtype: int64
# column : auto_model
# unique_values : auto_model
# RAM               43
# Wrangler          42
# A3                37
# Neon              37
# MDX               36
# Jetta             35
# Passat            33
# A5                32
# Legacy            32
# Pathfinder        31
# Malibu            30
# 92x               28
# Camry             28
# Forrestor         28
# F150              27
# 95                27
# E400              27
# 93                25
# Grand Cherokee    25
# Escape            24
# Tahoe             24
# Maxima            24
# Ultima            23
# X5                23
# Highlander        22
# Civic             22
# Silverado         22
# Fusion            21
# ML350             20
# Impreza           20
# Corolla           20
# TL                20
# CRV               20
# C300              18
# 3 Series          18
# X6                16
# M5                15
# Accord            13
# RSX               12
# Name: count, dtype: int64
# column : auto_year
# unique_values : auto_year
# 1995    56
# 1999    55
# 2005    54
# 2006    53
# 2011    53
# 2007    52
# 2003    51
# 2009    50
# 2010    50
# 2013    49
# 2002    49
# 2015    47
# 1997    46
# 2012    46
# 2008    45
# 2014    44
# 2001    42
# 2000    42
# 1998    40
# 2004    39
# 1996    37
# Name: count, dtype: int64
# column : fraud_reported
# unique_values : fraud_reported
# N    753
# Y    247
# Name: count, dtype: int64
# column : _c39
# unique_values : Series([], Name: count, dtype: int64)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### **2.2.2** Identify and drop any columns that are completely empty <font color="red">[1 Mark]</font>

# %%
# Identify and drop any columns that are completely empty
df = df.drop('_c39',axis=1)

# %% [markdown]
# #### **2.2.3** Identify and drop rows where features have illogical or invalid values, such as negative values for features that should only have positive values <font color="red">[1 Mark]</font>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
#  13  insured_hobbies              1000 non-null   object
#  14  insured_relationship         1000 non-null   object
#  15  capital-gains                1000 non-null   int64
#  16  capital-loss                 1000 non-null   int64
#  17  incident_date                1000 non-null   object
#  18  incident_type                1000 non-null   object
#  19  collision_type               1000 non-null   object
#  20  incident_severity            1000 non-null   object
#  21  authorities_contacted        1000 non-null   object
#  22  incident_state               1000 non-null   object
#  23  incident_city                1000 non-null   object
#  24  incident_location            1000 non-null   object
#  25  incident_hour_of_the_day     1000 non-null   int64
#  26  number_of_vehicles_involved  1000 non-null   int64
#  27  property_damage              1000 non-null   object
#  28  bodily_injuries              1000 non-null   int64
#  29  witnesses                    1000 non-null   int64
#  30  police_report_available      1000 non-null   object
#  31  total_claim_amount           1000 non-null   int64
#  32  injury_claim                 1000 non-null   int64
#  33  property_claim               1000 non-null   int64
#  34  vehicle_claim                1000 non-null   int64
#  35  auto_make                    1000 non-null   object
#  36  auto_model                   1000 non-null   object
#  37  auto_year                    1000 non-null   int64
#  38  fraud_reported               1000 non-null   object
# dtypes: float64(1), int64(17), object(21)
# memory usage: 304.8+ KB

# %%
# Identify and drop rows where features have illogical or invalid values, such as negative values for features that should only have positive values
columns_to_be_positive = [
    'months_as_customer', 'age', 'capital-gains', 'capital-loss', 
    'number_of_vehicles_involved', 'witnesses',
    'total_claim_amount', 'injury_claim', 
    'property_claim', 'vehicle_claim'
]

# %%
df[df[columns_to_be_positive] < 0].count()
# Out:
# months_as_customer               0
# age                              0
# policy_number                    0
# policy_bind_date                 0
# policy_state                     0
# policy_csl                       0
# policy_deductable                0
# policy_annual_premium            0
# umbrella_limit                   0
# insured_zip                      0
# insured_sex                      0
# insured_education_level          0
# insured_occupation               0
# insured_hobbies                  0
# insured_relationship             0
# capital-gains                    0
# capital-loss                   525
# incident_date                    0
# incident_type                    0
# collision_type                   0
# incident_severity                0
# authorities_contacted            0
# incident_state                   0
# incident_city                    0
# incident_location                0
# incident_hour_of_the_day         0
# number_of_vehicles_involved      0
# property_damage                  0
# bodily_injuries                  0
# witnesses                        0
# police_report_available          0
# total_claim_amount               0
# injury_claim                     0
# property_claim                   0
# vehicle_claim                    0
# auto_make                        0
# auto_model                       0
# auto_year                        0
# fraud_reported                   0
# dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.histplot(df['capital-loss'], bins=30, kde=True)
plt.title("Capital Loss - Before Cleaning")
plt.xlabel("capital-loss")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #### **2.2.4** Identify and remove columns where a large proportion of the values are unique or near-unique, as these columns are likely to be identifiers or have very limited predictive power <font color="red">[1 Mark]</font>

# %%
# Identify and remove columns that are likely to be identifiers or have very limited predictive power
df = df.drop('_c39',axis=1)

# %%
# Check the dataset
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... witnesses police_report_available total_claim_amount  \
# 0       466132  ...         2                     YES              71610
# 1       468176  ...         0                       ?               5070
# 2       430632  ...         3                      NO              34650
# 3       608117  ...         2                      NO              63400
# 4       610706  ...         1                      NO               6500
#
#   injury_claim property_claim  vehicle_claim  auto_make auto_model auto_year  \
# 0         6510          13020          52080       Saab        92x      2004
# 1          780            780           3510   Mercedes       E400      2007
# 2         7700           3850          23100      Dodge        RAM      2007
# 3         6340           6340          50720  Chevrolet      Tahoe      2014
# 4         1300            650           4550     Accura        RSX      2009
#
#   fraud_reported
# 0              Y
# 1              Y
# 2              N
# 3              Y
# 4              N
#
# [5 rows x 39 columns]

# %% [markdown]
# ### **2.3 Fix Data Types** <font color = red>[3 marks]</font>
# Carefully examine the dataset and identify columns that contain date or time information but are not stored as the appropriate data type. Convert these columns to the correct datetime data type to enable proper analysis and manipulation of temporal information.

# %%
# Fix the data types of the columns with incorrect data types
df.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_number                    int64
# policy_bind_date                object
# policy_state                    object
# policy_csl                      object
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                     object
# insured_education_level         object
# insured_occupation              object
# insured_hobbies                 object
# insured_relationship            object
# capital-gains                    int64
# capital-loss                     int64
# incident_date                   object
# incident_type                   object
# collision_type                  object
# incident_severity               object
# authorities_contacted           object
# incident_state                  object
# incident_city                   object
# incident_location               object
# incident_hour_of_the_day         int64
# number_of_vehicles_involved      int64
# property_damage                 object
# bodily_injuries                  int64
# witnesses                        int64
# police_report_available         object
# total_claim_amount               int64
# injury_claim                     int64
# property_claim                   int64
# vehicle_claim                    int64
# auto_make                       object
# auto_model                      object
# auto_year                        int64
# fraud_reported                  object
# dtype: object

# %%
df['policy_bind_date'] = pd.to_datetime(df['policy_bind_date'], errors='coerce')
df['incident_date'] = pd.to_datetime(df['incident_date'], errors='coerce')

# %%
# Check the features of the data again
df.dtypes
# Out:
# months_as_customer                      int64
# age                                     int64
# policy_number                           int64
# policy_bind_date               datetime64[ns]
# policy_state                           object
# policy_csl                             object
# policy_deductable                       int64
# policy_annual_premium                 float64
# umbrella_limit                          int64
# insured_zip                             int64
# insured_sex                            object
# insured_education_level                object
# insured_occupation                     object
# insured_hobbies                        object
# insured_relationship                   object
# capital-gains                           int64
# capital-loss                            int64
# incident_date                  datetime64[ns]
# incident_type                          object
# collision_type                         object
# incident_severity                      object
# authorities_contacted                  object
# incident_state                         object
# incident_city                          object
# incident_location                      object
# incident_hour_of_the_day                int64
# number_of_vehicles_involved             int64
# property_damage                        object
# bodily_injuries                         int64
# witnesses                               int64
# police_report_available                object
# total_claim_amount                      int64
# injury_claim                            int64
# property_claim                          int64
# vehicle_claim                           int64
# auto_make                              object
# auto_model                             object
# auto_year                               int64
# fraud_reported                         object
# dtype: object

# %% [markdown]
# ## **3. Train-Validation Split** <font color = red>[5 marks]</font>

# %% [markdown]
# ### **3.1 Import required libraries**

# %%
# Import train-test-split
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### **3.2 Define feature and target variables** <font color = red>[2 Marks]</font>

# %%
# Put all the feature variables in X
X = df.drop('fraud_reported', axis=1)

# Put the target variable in y
y = df['fraud_reported']

# %% [markdown]
# ### **3.3 Split the data** <font color="red">[3 Marks]</font>

# %%
# Split the dataset into 70% train and 30% validation and use stratification on the target variable
X_train, X_val, y_train, y_val = train_test_split(
    X, y, 
    test_size=0.3, 
    stratify=y, 
    random_state=42
)
# Reset index for all train and test sets
X_train = X_train.reset_index(drop=True)
X_val = X_val.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_val = y_val.reset_index(drop=True)

# %% [markdown]
# ## **4. EDA on training data** <font color = red>[20 marks]</font>

# %% [markdown]
# ### **4.1 Perform univariate analysis** <font color = red>[5 marks]</font>

# %% [markdown]
# #### **4.1.1** Identify and select numerical columns from training data for univariate analysis <font color = "red">[1 Mark]</font>

# %%
# Select numerical columns
numerical_cols = [
    'months_as_customer',
    'age',
    'policy_number',
    'policy_deductable',
    'policy_annual_premium',
    'umbrella_limit',
    'insured_zip',
    'capital-gains',
    'capital-loss',
    'incident_hour_of_the_day',
    'number_of_vehicles_involved',
    'bodily_injuries',
    'witnesses',
    'total_claim_amount',
    'injury_claim',
    'property_claim',
    'vehicle_claim',
    'auto_year'
]

# %% [markdown]
# #### **4.1.2** Visualise the distribution of selected numerical features using appropriate plots to understand their characteristics <font color = "red">[4 Marks]</font>

# %%
# Plot all the numerical columns to understand their distribution
X_train[numerical_cols].hist(bins=50,figsize=(20,15))
plt.show()

# %% [markdown]
# ### **4.2 Perform correlation analysis** <font color="red">[3 Marks]</font>

# %% [markdown]
#  Investigate the relationships between numerical features to identify potential multicollinearity or dependencies. Visualise the correlation structure using an appropriate method to gain insights into feature relationships.

# %%
import seaborn as sns

# %%
# Create correlation matrix for numerical columns
corr_matrix = X_train[numerical_cols].corr()
# Plot Heatmap of the correlation matrix
sns.heatmap(corr_matrix,cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ### **4.3 Check class balance** <font color="red">[2 Marks]</font>

# %% [markdown]
# Examine the distribution of the target variable to identify potential class imbalances using visualisation for better understanding.

# %%
# Plot a bar chart to check class balance
plt.figure(figsize=(6, 4))
sns.countplot(x=y_train)

plt.title("Class Balance")
plt.xlabel("Fraud Reported")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### **4.4 Perform bivariate analysis** <font color="red">[10 Marks]</font>

# %% [markdown]
# #### **4.4.1** Target likelihood analysis for categorical variables. <font color="red">[5 Marks]</font>
# Investigate the relationships between categorical features and the target variable by analysing the target event likelihood (for the `'Y'` event) for each level of every relevant categorical feature. Through this analysis, identify categorical features that do not contribute much in explaining the variation in the target variable.

# %%
# Write a function to calculate and analyse the target variable likelihood for categorical features

y_train_bin = y_train.map({'Y': 1, 'N': 0})
train_data = X_train.copy()
train_data['fraud_reported'] = y_train_bin


categorical_cols = [
    'policy_state', 'policy_csl', 'insured_sex', 'insured_education_level',
    'insured_occupation', 'insured_hobbies', 'insured_relationship',
    'incident_type', 'collision_type', 'incident_severity',
    'authorities_contacted', 'incident_state', 'incident_city',
    'property_damage', 'police_report_available',
    'auto_make', 'auto_model'
]


for col in categorical_cols:
    cat_likelihood = pd.concat([X_train[col], y_train_bin], axis=1).groupby(col).mean().sort_values(by='fraud_reported', ascending=False)
    print(f'{col} : {cat_likelihood}')
# Out:
# policy_state :               fraud_reported
# policy_state
# OH                  0.258475
# IN                  0.244344
# IL                  0.238683
# policy_csl :             fraud_reported
# policy_csl
# 100/300           0.276860
# 250/500           0.234127
# 500/1000          0.228155
# insured_sex :              fraud_reported
# insured_sex
# FEMALE             0.248663
# MALE               0.245399
# insured_education_level :                          fraud_reported
# insured_education_level
# MD                             0.277778
# PhD                            0.261905
# JD                             0.258065
# College                        0.250000
# Associate                      0.242991
# Masters                        0.242718
# High School                    0.205357
# insured_occupation :                     fraud_reported
# insured_occupation
# transport-moving          0.400000
# exec-managerial           0.333333
# craft-repair              0.301887
# farming-fishing           0.272727
# sales                     0.263158
# armed-forces              0.260870
# tech-support              0.250000
# machine-op-inspct         0.235294
# other-service             0.204545
# protective-serv           0.204545
# prof-specialty            0.203390
# priv-house-serv           0.176471
# adm-clerical              0.166667
# handlers-cleaners         0.147059
# insured_hobbies :                  fraud_reported
# insured_hobbies
# chess                  0.878788
# cross-fit              0.826087
# polo                   0.333333
# yachting               0.323529
# hiking                 0.300000
# board-games            0.250000
# base-jumping           0.250000
# paintball              0.244898
# reading                0.234043
# video-games            0.222222
# skydiving              0.210526
# sleeping               0.192308
# bungie-jumping         0.179487
# exercise               0.157895
# movies                 0.135135
# camping                0.108108
# dancing                0.108108
# basketball             0.105263
# kayaking               0.095238
# golf                   0.073171
# insured_relationship :                       fraud_reported
# insured_relationship
# other-relative              0.290076
# unmarried                   0.280374
# wife                        0.276786
# not-in-family               0.247863
# husband                     0.212389
# own-child                   0.175000
# incident_type :                           fraud_reported
# incident_type
# Single Vehicle Collision        0.292419
# Multi-vehicle Collision         0.272727
# Parked Car                      0.089552
# Vehicle Theft                   0.084746
# collision_type :                  fraud_reported
# collision_type
# Rear Collision         0.301435
# Front Collision        0.282486
# Side Collision         0.260638
# ?                      0.087302
# incident_severity :                    fraud_reported
# incident_severity
# Major Damage             0.596939
# Total Loss               0.148718
# Minor Damage             0.093117
# Trivial Damage           0.064516
# authorities_contacted :                        fraud_reported
# authorities_contacted
# Ambulance                    0.304965
# Fire                         0.297297
# Other                        0.279720
# Police                       0.204082
# Unknown                      0.083333
# incident_state :                 fraud_reported
# incident_state
# OH                    0.470588
# SC                    0.313609
# NC                    0.305882
# PA                    0.260870
# VA                    0.259740
# NY                    0.204420
# WV                    0.155405
# incident_city :                fraud_reported
# incident_city
# Arlington            0.303922
# Columbus             0.270270
# Springfield          0.256637
# Northbrook           0.231707
# Riverwood            0.230769
# Hillsdale            0.221154
# Northbend            0.206186
# property_damage :                  fraud_reported
# property_damage
# ?                      0.289157
# YES                    0.280193
# NO                     0.176230
# police_report_available :                          fraud_reported
# police_report_available
# ?                              0.260331
# NO                             0.254098
# YES                            0.224299
# auto_make :             fraud_reported
# auto_make
# Audi              0.361702
# Mercedes          0.333333
# Ford              0.307692
# BMW               0.280000
# Chevrolet         0.272727
# Toyota            0.255814
# Honda             0.243243
# Suburu            0.241935
# Jeep              0.224490
# Volkswagen        0.224490
# Saab              0.210526
# Dodge             0.200000
# Nissan            0.188679
# Accura            0.137255
# auto_model :                 fraud_reported
# auto_model
# Silverado             0.500000
# X6                    0.454545
# F150                  0.444444
# Civic                 0.428571
# A5                    0.409091
# Tahoe                 0.400000
# Maxima                0.352941
# C300                  0.333333
# ML350                 0.333333
# E400                  0.333333
# A3                    0.320000
# Forrestor             0.320000
# Grand Cherokee        0.315789
# Highlander            0.312500
# M5                    0.300000
# X5                    0.294118
# Impreza               0.272727
# Camry                 0.266667
# Fusion                0.250000
# 93                    0.235294
# Neon                  0.227273
# Passat                0.227273
# 92x                   0.227273
# Jetta                 0.222222
# Escape                0.222222
# Accord                0.200000
# RAM                   0.178571
# MDX                   0.172414
# Wrangler              0.166667
# 95                    0.166667
# Corolla               0.166667
# Ultima                0.157895
# Legacy                0.153846
# RSX                   0.111111
# 3 Series              0.083333
# TL                    0.076923
# CRV                   0.076923
# Pathfinder            0.058824
# Malibu                0.000000

# %% [markdown]
# #### **4.4.2** Explore the relationships between numerical features and the target variable to understand their impact on the target outcome using appropriate visualisation techniques to identify trends and potential interactions. <font color="red">[5 Marks]</font>

# %%
# Visualise the relationship between numerical features and the target variable to understand their impact on the target outcome
for col in numerical_cols:
    plt.figure(figsize=(14, 5))
    plt.subplot(2, 4, 4)
    sns.boxplot(x='fraud_reported', y=col, data=train_data)
    plt.title(f"{col} - Boxplot by Fraud")
   
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## **5. EDA on validation data** <font color = red>[OPTIONAL]</font>

# %% [markdown]
# ### **5.1 Perform univariate analysis**

# %% [markdown]
# #### **5.1.1** Identify and select numerical columns from training data for univariate analysis.

# %%
# Select numerical columns

# %% [markdown]
# #### **5.1.2** Visualise the distribution of selected numerical features using appropriate plots to understand their characteristics.

# %%
# Plot all the numerical columns to understand their distribution

# %% [markdown]
# ### **5.2 Perform correlation analysis**

# %% [markdown]
#  Investigate the relationships between numerical features to identify potential multicollinearity or dependencies. Visualise the correlation structure using an appropriate method to gain insights into feature relationships.

# %%
# Create correlation matrix for numerical columns

# Plot Heatmap of the correlation matrix

# %% [markdown]
# ### **5.3 Check class balance**

# %% [markdown]
# Examine the distribution of the target variable to identify potential class imbalances. Visualise the distribution for better understanding.

# %%
# Plot a bar chart to check class balance

# %% [markdown]
# ### **5.4 Perform bivariate analysis**

# %% [markdown]
# #### **5.4.1** Target likelihood analysis for categorical variables.
# Investigate the relationships between categorical features and the target variable by analysing the target event likelihood (for the `'Y'` event) for each level of every relevant categorical feature. Through this analysis, identify categorical features that do not contribute much in explaining the variation in the target variable.

# %%
# Write a function to calculate and analyse the target variable likelihood for categorical features

# %% [markdown]
# #### **5.4.2** Explore the relationships between numerical features and the target variable to understand their impact on the target outcome. Utilise appropriate visualisation techniques to identify trends and potential interactions.

# %%
# Visualise the relationship between numerical features and the target variable to understand their impact on the target outcome

# %% [markdown]
# ## **6. Feature Engineering** <font color = red>[25 marks]</font>

# %% [markdown]
# ### **6.1 Perform resampling** <font color="red">[3 Marks]</font>

# %% [markdown]
# Handle class imbalance in the training data by applying resampling technique.
#
# Use the **RandomOverSampler** technique to balance the data and handle class imbalance. This method increases the number of samples in the minority class by randomly duplicating them, creating synthetic data points with similar characteristics. This helps prevent the model from being biased toward the majority class and improves its ability to predict the minority class more accurately.
#
# **Note:** You can try other resampling techniques to handle class imbalance

# %%
# Import RandomOverSampler from imblearn library
from imblearn.over_sampling import RandomOverSampler

# Perform resampling on training data
randomSampler= RandomOverSampler(random_state=42)
X_train_resampled, y_train_resampled = randomSampler.fit_resample(X_train, y_train_bin)

# %% [markdown]
# ### **6.2 Feature Creation** <font color="red">[4 marks]</font>

# %% [markdown]
# Create new features from existing ones to enhance the model's ability to capture patterns in the data. This may involve deriving features from date/time columns, combining features, or creating interaction terms.

# %%
X_train_resampled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1054 entries, 0 to 1053
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1054 non-null   int64
#  1   age                          1054 non-null   int64
#  2   policy_number                1054 non-null   int64
#  3   policy_bind_date             1054 non-null   datetime64[ns]
#  4   policy_state                 1054 non-null   object
#  5   policy_csl                   1054 non-null   object
#  6   policy_deductable            1054 non-null   int64
#  7   policy_annual_premium        1054 non-null   float64
#  8   umbrella_limit               1054 non-null   int64
#  9   insured_zip                  1054 non-null   int64
#  10  insured_sex                  1054 non-null   object
#  11  insured_education_level      1054 non-null   object
#  12  insured_occupation           1054 non-null   object
#  13  insured_hobbies              1054 non-null   object
#  14  insured_relationship         1054 non-null   object
#  15  capital-gains                1054 non-null   int64
#  16  capital-loss                 1054 non-null   int64
#  17  incident_date                1054 non-null   datetime64[ns]
#  18  incident_type                1054 non-null   object
#  19  collision_type               1054 non-null   object
#  20  incident_severity            1054 non-null   object
#  21  authorities_contacted        1054 non-null   object
#  22  incident_state               1054 non-null   object
#  23  incident_city                1054 non-null   object
#  24  incident_location            1054 non-null   object
#  25  incident_hour_of_the_day     1054 non-null   int64
#  26  number_of_vehicles_involved  1054 non-null   int64
#  27  property_damage              1054 non-null   object
#  28  bodily_injuries              1054 non-null   int64
#  29  witnesses                    1054 non-null   int64
#  30  police_report_available      1054 non-null   object
#  31  total_claim_amount           1054 non-null   int64
#  32  injury_claim                 1054 non-null   int64
#  33  property_claim               1054 non-null   int64
#  34  vehicle_claim                1054 non-null   int64
#  35  auto_make                    1054 non-null   object
#  36  auto_model                   1054 non-null   object
#  37  auto_year                    1054 non-null   int64
# dtypes: datetime64[ns](2), float64(1), int64(17), object(18)
# memory usage: 313.0+ KB

# %%
# Create new features based on your understanding for both training and validation data
X_train_resampled['policy_bind_year'] = X_train_resampled['policy_bind_date'].dt.year
X_train_resampled['policy_bind_month'] = X_train_resampled['policy_bind_date'].dt.month

# %%
X_train_resampled['incident_year'] = X_train_resampled['incident_date'].dt.year
X_train_resampled['incident_month'] = X_train_resampled['incident_date'].dt.month
X_train_resampled['incident_dayofweek'] = X_train_resampled['incident_date'].dt.dayofweek

# %%
X_train_resampled['days_from_policy_date'] = (X_train_resampled['incident_date'] - X_train_resampled['policy_bind_date']).dt.days

# %%
X_val['policy_bind_year'] = X_val['policy_bind_date'].dt.year
X_val['policy_bind_month'] = X_val['policy_bind_date'].dt.month

X_val['incident_year'] = X_val['incident_date'].dt.year
X_val['incident_month'] = X_val['incident_date'].dt.month
X_val['incident_dayofweek'] = X_val['incident_date'].dt.dayofweek

X_val['days_from_policy_date'] = (X_val['incident_date'] - X_val['policy_bind_date']).dt.days

# %%
X_train_resampled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1054 entries, 0 to 1053
# Data columns (total 44 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1054 non-null   int64
#  1   age                          1054 non-null   int64
#  2   policy_number                1054 non-null   int64
#  3   policy_bind_date             1054 non-null   datetime64[ns]
#  4   policy_state                 1054 non-null   object
#  5   policy_csl                   1054 non-null   object
#  6   policy_deductable            1054 non-null   int64
#  7   policy_annual_premium        1054 non-null   float64
#  8   umbrella_limit               1054 non-null   int64
#  9   insured_zip                  1054 non-null   int64
#  10  insured_sex                  1054 non-null   object
#  11  insured_education_level      1054 non-null   object
#  12  insured_occupation           1054 non-null   object
#  13  insured_hobbies              1054 non-null   object
#  14  insured_relationship         1054 non-null   object
#  15  capital-gains                1054 non-null   int64
#  16  capital-loss                 1054 non-null   int64
#  17  incident_date                1054 non-null   datetime64[ns]
#  18  incident_type                1054 non-null   object
#  19  collision_type               1054 non-null   object
#  20  incident_severity            1054 non-null   object
#  21  authorities_contacted        1054 non-null   object
#  22  incident_state               1054 non-null   object
#  23  incident_city                1054 non-null   object
#  24  incident_location            1054 non-null   object
#  25  incident_hour_of_the_day     1054 non-null   int64
#  26  number_of_vehicles_involved  1054 non-null   int64
#  27  property_damage              1054 non-null   object
#  28  bodily_injuries              1054 non-null   int64
#  29  witnesses                    1054 non-null   int64
#  30  police_report_available      1054 non-null   object
#  31  total_claim_amount           1054 non-null   int64
#  32  injury_claim                 1054 non-null   int64
#  33  property_claim               1054 non-null   int64
#  34  vehicle_claim                1054 non-null   int64
#  35  auto_make                    1054 non-null   object
#  36  auto_model                   1054 non-null   object
#  37  auto_year                    1054 non-null   int64
#  38  policy_bind_year             1054 non-null   int32
#  39  policy_bind_month            1054 non-null   int32
#  40  incident_year                1054 non-null   int32
#  41  incident_month               1054 non-null   int32
#  42  incident_dayofweek           1054 non-null   int32
#  43  days_from_policy_date        1054 non-null   int64
# dtypes: datetime64[ns](2), float64(1), int32(5), int64(18), object(18)
# memory usage: 341.9+ KB

# %%
X_train_resampled.describe()
# Out:
#        months_as_customer          age  policy_number  \
# count         1054.000000  1054.000000    1054.000000
# mean           208.009488    39.252372  530145.003795
# min              0.000000    20.000000  100804.000000
# 25%            119.000000    32.000000  306117.250000
# 50%            204.000000    38.500000  515940.000000
# 75%            283.000000    45.000000  752504.000000
# max            479.000000    64.000000  999435.000000
# std            114.894377     9.277554  261517.991261
#
#                     policy_bind_date  policy_deductable  \
# count                           1054        1054.000000
# mean   2002-01-12 15:57:43.377609088        1162.713472
# min              1990-01-08 00:00:00         500.000000
# 25%              1995-07-16 00:00:00         500.000000
# 50%              2002-02-01 00:00:00        1000.000000
# 75%              2008-02-21 06:00:00        2000.000000
# max              2015-02-22 00:00:00        2000.000000
# std                              NaN         622.729219
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1054.000000    1.054000e+03    1054.000000    1054.000000
# mean             1257.785313    1.135674e+06  506773.572106   25710.626186
# min               433.330000   -1.000000e+06  430104.000000       0.000000
# 25%              1091.730000    0.000000e+00  450451.500000       0.000000
# 50%              1270.420000    0.000000e+00  468985.000000   13600.000000
# 75%              1400.370000    0.000000e+00  604364.750000   50700.000000
# max              2047.590000    1.000000e+07  620869.000000  100500.000000
# std               236.827356    2.302317e+06   73278.913284   27550.585797
#
#         capital-loss  ...  injury_claim  property_claim  vehicle_claim  \
# count    1054.000000  ...   1054.000000     1054.000000    1054.000000
# mean   -26040.227704  ...   7812.314991     7923.036053   40022.685009
# min   -111100.000000  ...      0.000000        0.000000    1440.000000
# 25%    -51100.000000  ...   4865.000000     5055.000000   33510.000000
# 50%    -11900.000000  ...   6870.000000     6900.000000   43680.000000
# 75%         0.000000  ...  11700.000000    11330.000000   51280.000000
# max         0.000000  ...  21450.000000    23670.000000   79560.000000
# std     28205.248856  ...   4890.971813     4924.998203   18054.910992
#
#          auto_year  policy_bind_year  policy_bind_month  incident_year  \
# count  1054.000000       1054.000000         1054.00000         1054.0
# mean   2004.811195       2001.543643            6.40038         2015.0
# min    1995.000000       1990.000000            1.00000         2015.0
# 25%    2000.000000       1995.000000            3.00000         2015.0
# 50%    2005.000000       2002.000000            6.00000         2015.0
# 75%    2010.000000       2008.000000            9.00000         2015.0
# max    2015.000000       2015.000000           12.00000         2015.0
# std       5.960891          7.354895            3.39278            0.0
#
#        incident_month  incident_dayofweek  days_from_policy_date
# count     1054.000000         1054.000000            1054.000000
# mean         1.456357            3.062619            4764.204934
# min          1.000000            0.000000             -20.000000
# 25%          1.000000            1.000000            2526.000000
# 50%          1.000000            3.000000            4737.000000
# 75%          2.000000            5.000000            7147.000000
# max          3.000000            6.000000            9172.000000
# std          0.515194            1.998543            2684.811779
#
# [8 rows x 26 columns]

# %%
X_train_resampled['policy_csl'].unique()
# Out:
# array(['100/300', '500/1000', '250/500'], dtype=object)

# %% [markdown]
# ### **6.3 Handle redundant columns** <font color="red">[3 marks]</font>

# %% [markdown]
# Analyse the data to identify features that may be redundant or contribute minimal information toward predicting the target variable and drop them.
#
# - You can consider features that exhibit high correlation with other variables, which you may have observed during the EDA phase.
# - Features that don't strongly influence the prediction, which you may have observed during the EDA phase.
# - Categorical columns with low value counts for some levels can be remapped to reduce number of unique levels, and features with very high counts for just one level may be removed, as they resemble unique identifier columns and do not provide substantial predictive value.
# - Additionally, eliminate any columns from which the necessary features have already been extracted in the preceding step.

# %%
# Drop redundant columns from training and validation data
columns_to_drop = ['policy_bind_date', 'incident_date', 'policy_number', 'total_claim_amount', 'incident_location']
X_train_resampled = X_train_resampled.drop(columns=columns_to_drop)
X_val = X_val.drop(columns=columns_to_drop)

# %% [markdown]
# ### **6.4 Combine values in Categorical Columns** <font color="red">[6 Marks]</font>
# During the EDA process, categorical columns with multiple unique values may be identified. To enhance model performance, it is essential to refine these categorical features by grouping values that have low frequency or provide limited predictive information.
#
# Combine categories that occur infrequently or exhibit similar behavior to reduce sparsity and improve model generalisation.

# %%
# Combine categories that have low frequency or provide limited predictive information
def combine_rare_categories(df, column, threshold=10):
    total_count = df[column].value_counts()
    rare = total_count[total_count < threshold].index
    df[column + '_grouped'] = df[column].replace(rare, 'Other')
    return df
column = 'auto_model'
combine_rare_categories(X_train_resampled, column,25)
# Out:
#       months_as_customer  age policy_state policy_csl  policy_deductable  \
# 0                    428   54           IN    100/300               2000
# 1                      0   32           OH   500/1000               1000
# 2                     47   37           IN    250/500               2000
# 3                    283   48           OH   500/1000               1000
# 4                    343   48           IN    250/500                500
# ...                  ...  ...          ...        ...                ...
# 1049                 254   40           IN    100/300                500
# 1050                 147   37           IN   500/1000               2000
# 1051                 234   41           IN    100/300                500
# 1052                  84   32           IL   500/1000                500
# 1053                 184   38           IL    250/500               1000
#
#       policy_annual_premium  umbrella_limit  insured_zip insured_sex  \
# 0                   1506.21               0       453407        MALE
# 1                   1377.04               0       441363        MALE
# 2                   1241.97               0       430104        MALE
# 3                   1474.66               0       446755      FEMALE
# 4                   1451.54         3000000       473412        MALE
# ...                     ...             ...          ...         ...
# 1049                1927.87               0       609317        MALE
# 1050                1375.29               0       609226      FEMALE
# 1051                 951.56               0       455426      FEMALE
# 1052                1694.09         7000000       603732      FEMALE
# 1053                1437.53               0       437889      FEMALE
#
#      insured_education_level  ...   auto_make auto_model auto_year  \
# 0                    Masters  ...      Nissan     Ultima      2009
# 1                    College  ...      Accura        MDX      2002
# 2                High School  ...        Jeep   Wrangler      2011
# 3                         JD  ...  Volkswagen      Jetta      2003
# 4                         JD  ...    Mercedes       C300      2003
# ...                      ...  ...         ...        ...       ...
# 1049                      MD  ...       Honda      Civic      1996
# 1050                 Masters  ...        Ford     Fusion      2015
# 1051                      JD  ...   Chevrolet      Tahoe      2007
# 1052               Associate  ...         BMW         X6      1995
# 1053                 College  ...       Dodge        RAM      2013
#
#       policy_bind_year  policy_bind_month incident_year incident_month  \
# 0                 2004                  2          2015              1
# 1                 2011                  2          2015              1
# 2                 2008                  3          2015              1
# 3                 2003                  1          2015              2
# 4                 2009                 11          2015              1
# ...                ...                ...           ...            ...
# 1049              1994                  6          2015              1
# 1050              2013                  4          2015              1
# 1051              1990                  5          2015              2
# 1052              2001                  3          2015              1
# 1053              1994                  9          2015              2
#
#      incident_dayofweek days_from_policy_date auto_model_grouped
# 0                     3                  4005             Ultima
# 1                     5                  1429                MDX
# 2                     0                  2486           Wrangler
# 3                     1                  4427              Jetta
# 4                     3                  1892              Other
# ...                 ...                   ...                ...
# 1049                  2                  7533              Civic
# 1050                  5                   651             Fusion
# 1051                  6                  9034              Tahoe
# 1052                  4                  5080                 X6
# 1053                  0                  7448                RAM
#
# [1054 rows x 40 columns]

# %%
X_train_resampled = X_train_resampled.drop('auto_model_grouped',axis=1)

# %%
cols = ['collision_type', 'property_damage']
X_train_resampled[cols] = X_train_resampled[cols].replace('?', 'others')
X_val[cols] = X_val[cols].replace('?', 'others')

# %% [markdown]
# ### **6.5 Dummy variable creation** <font color="red">[6 Marks]</font>
# Transform categorical variables into numerical representations using dummy variables. Ensure consistent encoding between training and validation data.

# %% [markdown]
# #### **6.5.1** Identify categorical columns for dummy variable creation <font color="red">[1 Mark]</font>

# %%
# Identify the categorical columns for creating dummy variables
cat_cols = X_train_resampled.select_dtypes(include=['object', 'category']).columns.tolist()
print(cat_cols)
# Out:
# ['policy_state', 'policy_csl', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'property_damage', 'police_report_available', 'auto_make', 'auto_model']

# %% [markdown]
# #### **6.5.2** Create dummy variables for categorical columns in training data <font color="red">[2 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for categorical columns in training data
X_train_dummies = pd.get_dummies(X_train_resampled, columns=cat_cols, drop_first=True)

# %% [markdown]
# #### **6.5.3** Create dummy variables for categorical columns in validation data <font color="red">[2 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for categorical columns in validation data
X_val_dummies = pd.get_dummies(X_val, columns=cat_cols, drop_first=True)

# %% [markdown]
# #### **6.5.4** Create dummy variable for dependent feature in training and validation data <font color = "red">[1 Mark]</font>

# %%
# Create dummy variable for dependent feature in training data
y_train_bin = y_train_resampled.map({'Y': 1, 'N': 0})
# Create dummy variable for dependent feature in validation data
y_val_bin = y_val.map({'Y': 1, 'N': 0})

# %% [markdown]
# ### **6.6 Feature scaling** <font color = red>[3 marks]</font>
# Scale numerical features to a common range to prevent features with larger values from dominating the model.  Choose a scaling method appropriate for the data and the chosen model. Apply the same scaling to both training and validation data.

# %%
# Import the necessary scaling tool from scikit-learn
num_cols = X_train_dummies.select_dtypes(include=['float64', 'int64', 'int32']).columns.tolist()
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = X_train_dummies.copy()
X_train_scaled[num_cols] = scaler.fit_transform(X_train_dummies[num_cols])



# Scale the numeric features present in the training data

# Scale the numeric features present in the validation data
X_val_scaled = X_val_dummies.copy()
X_val_scaled[num_cols] = scaler.transform(X_val_dummies[num_cols])

# %% [markdown]
# ## **7. Model Building** <font color = red>[50 marks]</font>

# %% [markdown]
# In this task, you will be building two machine learning models: Logistic Regression and Random Forest. Each model will go through a structured process to ensure optimal performance. The key steps for each model are outlined below:
#
# **Logistic Regression Model**
# - Feature Selection using RFECV – Identify the most relevant features using Recursive Feature Elimination with Cross-Validation.
# - Model Building and Multicollinearity Assessment – Build the logistic regression model and analyse statistical aspects such as p-values and VIFs to detect multicollinearity.
# - Model Training and Evaluation on Training Data – Fit the model on the training data and assess initial performance.
# - Finding the Optimal Cutoff – Determine the best probability threshold by analysing the sensitivity-specificity tradeoff and precision-recall tradeoff.
# - FInal Prediction and Evaluation on Training Data using the Optimal Cutoff – Generate final predictions using the selected cutoff and evaluate model performance.
#
# **Random Forest Model**
# - Get Feature Importances - Obtain the importance scores for each feature and select the important features to train the model.
# - Model Evaluation on Training Data – Assess performance metrics on the training data.
# - Check Model Overfitting using Cross-Validation – Evaluate generalisation by performing cross-validation.
# - Hyperparameter Tuning using Grid Search – Optimise model performance by fine-tuning hyperparameters.
# - Final Model and Evaluation on Training Data – Train the final model using the best parameters and assess its performance.

# %% [markdown]
# ### **7.1 Feature selection** <font color = red>[4 marks]</font>
# Identify and select the most relevant features for building a logistic regression model using Recursive Feature Elimination with Cross-Validation (RFECV).

# %% [markdown]
# #### **7.1.1** Import necessary libraries <font color="red">[1 Mark]</font>

# %%
# Import necessary libraries
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFECV
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# #### **7.1.2** Perform feature selection <font color="red">[2 Mark]</font>

# %%
print(y_train_resampled.unique())
print(y_train_resampled.value_counts(dropna=False))
# Out:
# [0 1]
# fraud_reported
# 0    527
# 1    527
# Name: count, dtype: int64

# %%
y_train_resampled = y_train_resampled.astype(str).str.strip()
print(y_train_resampled.unique())
# Out:
# ['0' '1']

# %%
# Apply RFECV to identify the most relevant features
lr = LogisticRegression(max_iter=1000, class_weight='balanced', random_state=42)
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
rfecv = RFECV(
    estimator=lr, 
    step=1, 
    cv=cv, 
    scoring='accuracy', 
    n_jobs=-1
)


rfecv.fit(X_train_scaled, y_train_resampled)
# Out:
# RFECV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#       estimator=LogisticRegression(class_weight='balanced', max_iter=1000,
#                                    random_state=42),
#       n_jobs=-1, scoring='accuracy')

# %%
# Display the features ranking by RFECV in a DataFrame
feature_ranking = pd.DataFrame({
    'Feature': X_train_scaled.columns,
    'Rank': rfecv.ranking_,
    'Support': rfecv.support_
}).sort_values(by='Rank')

display(feature_ranking)
# Out:
#                         Feature  Rank  Support
# 0            months_as_customer     1     True
# 96       property_damage_others     1     True
# 97   police_report_available_NO     1     True
# 98  police_report_available_YES     1     True
# 99               auto_make_Audi     1     True
# ..                          ...   ...      ...
# 59         insured_hobbies_polo     5    False
# 92     incident_city_Northbrook     6    False
# 16             policy_bind_year     7    False
# 26             insured_sex_MALE     8    False
# 18                incident_year     9    False
#
# [150 rows x 3 columns]

# %% [markdown]
# #### **7.1.2** Retain the selected features <font color="red">[1 Mark]</font>

# %%
# Put columns selected by RFECV into variable 'col'
col = X_train_scaled.columns[rfecv.support_].tolist()

# %% [markdown]
# ### **7.2 Build Logistic Regression Model** <font color = red>[12 marks]</font>
# After selecting the optimal features using RFECV, utilise these features to build a logistic regression model with Statsmodels. This approach enables a detailed statistical analysis of the model, including the assessment of p-values and Variance Inflation Factors (VIFs). Evaluating these metrics is crucial for detecting multicollinearity and ensuring that the selected predictors are not highly correlated.

# %% [markdown]
# #### **7.2.1** Select relevant features and add constant in training data <font color="red">[1 Mark]</font>

# %%
# Select only the columns selected by RFECV
X_train_final = X_train_scaled[col]

# %%
# Import statsmodels and add constant
import statsmodels.api as sm
X_train_const = sm.add_constant(X_train_final)
# Check the data
X_train_const.head()
# Out:
#    const  months_as_customer       age  policy_deductable  \
# 0    1.0            1.915629  1.590358           1.345182
# 1    1.0           -1.811300 -0.782083          -0.261415
# 2    1.0           -1.402035 -0.242892           1.345182
# 3    1.0            0.653001  0.943329          -0.261415
# 4    1.0            1.175467  0.943329          -1.064713
#
#    policy_annual_premium  umbrella_limit  insured_zip  capital-gains  \
# 0               1.049468       -0.493508    -0.728612      -0.933658
# 1               0.503790       -0.493508    -0.893049       1.296027
# 2              -0.066812       -0.493508    -1.046767       1.804425
# 3               0.916185       -0.493508    -0.819432      -0.933658
# 4               0.818515        0.810145    -0.455485      -0.933658
#
#    capital-loss  incident_hour_of_the_day  ...  auto_model_Pathfinder  \
# 0      0.058181                  0.626985  ...                  False
# 1     -0.534189                 -0.822867  ...                  False
# 2      0.923679                  0.916956  ...                  False
# 3     -0.715092                 -0.387911  ...                  False
# 4      0.923679                  0.192030  ...                  False
#
#    auto_model_RAM  auto_model_RSX  auto_model_Silverado  auto_model_TL  \
# 0           False           False                 False          False
# 1           False           False                 False          False
# 2           False           False                 False          False
# 3           False           False                 False          False
# 4           False           False                 False          False
#
#    auto_model_Tahoe  auto_model_Ultima  auto_model_Wrangler  auto_model_X5  \
# 0             False               True                False          False
# 1             False              False                False          False
# 2             False              False                 True          False
# 3             False              False                False          False
# 4             False              False                False          False
#
#    auto_model_X6
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#
# [5 rows x 143 columns]

# %% [markdown]
# #### **7.2.2** Fit logistic regression model <font color="red">[2 Marks]</font>

# %%
# Fit a logistic Regression model on X_train after adding a constant and output the summary
logit_model = sm.Logit(y_train_resampled, X_train_const)
result = logit_model.fit(maxiter=200)
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.200809
#          Iterations: 200
# /opt/anaconda3/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %% [markdown]
# **Model Interpretation**
#
# The output summary table will provide the features used for building model along with coefficient of each of the feature and their p-value. The p-value in a logistic regression model is used to assess the statistical significance of each coefficient. Lesser the p-value, more significant the feature is in the model.
#
# A positive coefficient will indicate that an increase in the value of feature would increase the odds of the event occurring. On the other hand, a negative coefficient means the opposite, i.e, an increase in the value of feature would decrease the odds of the event occurring.

# %% [markdown]
# Now check VIFs for presence of multicollinearity in the model.

# %% [markdown]
# #### **7.2.3** Evaluate VIF of features to assess multicollinearity <font color="red">[2 Marks]</font>

# %%
# Import 'variance_inflation_factor'
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Make a VIF DataFrame for all the variables present



vif_data = pd.DataFrame()
vif_data['feature'] = X_train_final.columns
vif_data['VIF'] = [variance_inflation_factor(X_train_final.values, i) for i in range(X_train_final.shape[1])]

# %% [markdown]
# Proceed to the next step if p-values and VIFs are within acceptable ranges. If you observe high p-values or VIFs, drop the features and retrain the model. <font color="red">[THIS IS OPTIONAL]</font>

# %% [markdown]
# #### **7.2.4** Make predictions on training data <font color = "red">[1 Mark]</font>

# %%
# Predict probabilities on training data
y_train_pred_prob = result.predict(X_train_const)

# Reshape if needed (for compatibility)
y_train_pred_prob = np.array(y_train_pred_prob)

# %% [markdown]
# #### **7.2.5** Create a DataFrame that includes actual fraud reported flags, predicted probabilities, and a column indicating predicted classifications based on a cutoff value of 0.5 <font color="red">[1 Mark]</font>

# %%
# Create output DataFrame
output_df = pd.DataFrame({
    'fraud_reported_actual': y_train_resampled,
    'predicted_prob': y_train_pred_prob
})

# Create predicted classifications based on 0.5 cutoff
output_df['predicted_label'] = (output_df['predicted_prob'] >= 0.5).astype(int)

output_df.head()
# Out:
#    fraud_reported_actual  predicted_prob  predicted_label
# 0                    0.0        0.026613                0
# 1                    0.0        0.000818                0
# 2                    0.0        0.000012                0
# 3                    0.0        0.002039                0
# 4                    0.0        0.000175                0

# %% [markdown]
# **Model performance evaluation**
#
# Evaluate the performance of the model based on predictions made on the training data.

# %% [markdown]
# #### **7.2.6** Check the accuracy of the model <font color = "red">[1 Mark]</font>

# %%
# Import metrics from sklearn for evaluation
from sklearn import metrics

# Check the accuracy of the model
accuracy = metrics.accuracy_score(output_df['fraud_reported_actual'], output_df['predicted_label'])
print( accuracy)
# Out:
# 0.9402277039848197

# %% [markdown]
# #### **7.2.7** Create a confusion matrix based on the predictions made on the training data <font color="red">[1 Mark]</font>

# %%
# Create confusion matrix
conf_matrix = metrics.confusion_matrix(output_df['fraud_reported_actual'], output_df['predicted_label'])
conf_matrix
# Out:
# array([[490,  37],
#        [ 26, 501]])

# %% [markdown]
# #### **7.2.8** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = conf_matrix.ravel()
print(f"TP: {tp}, TN: {tn}, FP: {fp}, FN: {fn}")
# Out:
# TP: 501, TN: 490, FP: 37, FN: 26

# %% [markdown]
# #### **7.2.9** Calculate sensitivity, specificity, precision, recall and F1-score <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity = tp / (tp + fn)

# Calculate the specificity
specificity = tn / (tn + fp)

# Calculate Precision
precision = tp / (tp + fp)

# Calculate Recall

recall = sensitivity
# Calculate F1 Score
f1 = 2 * (precision * recall) / (precision + recall)

# %% [markdown]
# ### **7.3 Find the Optimal Cutoff** <font color = red>[12 marks]</font>
# Find the optimal cutoff to improve model performance by evaluating various cutoff values and their impact on relevant metrics.

# %% [markdown]
# #### **7.3.1** Plot ROC Curve  to visualise the trade-off between true positive rate and false positive rate across different classification thresholds <font color="red">[2 Marks]</font>

# %%
# Import libraries or function to plot the ROC curve
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# True labels and predicted probabilities
y_true = output_df['fraud_reported_actual']
y_score = output_df['predicted_prob']
fpr, tpr, thresholds = roc_curve(y_true, y_score)
roc_auc = auc(fpr, tpr)



# Define ROC function
plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0,1], [0,1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %%
# Call the ROC function
plt.plot(fpr, tpr, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0,1], [0,1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %% [markdown]
# **Sensitivity and Specificity tradeoff**
#
# After analysing the area under the curve of the ROC, check the sensitivity and specificity tradeoff to find the optimal cutoff point.

# %% [markdown]
# #### **7.3.2** Predict on training data at various probability cutoffs <font color="red">[1 Mark]</font>

# %%
# Create columns with different probability cutoffs to explore the impact of cutoff on model performance
cutoffs = np.arange(0.0, 1.01, 0.01)
metrics_list = []

for cutoff in cutoffs:
    predicted = (y_score >= cutoff).astype(int)
    tn, fp, fn, tp = metrics.confusion_matrix(y_true, predicted).ravel()
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    metrics_list.append([cutoff, accuracy, sensitivity, specificity])

cutoff_df = pd.DataFrame(metrics_list, columns=['cutoff', 'accuracy', 'sensitivity', 'specificity'])

# %% [markdown]
# #### **7.3.3** Plot accuracy, sensitivity, specificity at different values of probability cutoffs <font color="red">[2 Marks]</font>

# %%
# Create a DataFrame to see the values of accuracy, sensitivity, and specificity at different values of probability cutoffs
plt.figure(figsize=(8,5))
plt.plot(cutoff_df['cutoff'], cutoff_df['accuracy'], label='Accuracy')
plt.plot(cutoff_df['cutoff'], cutoff_df['sensitivity'], label='Sensitivity (Recall)')
plt.plot(cutoff_df['cutoff'], cutoff_df['specificity'], label='Specificity')
plt.xlabel('Probability Cutoff')
plt.ylabel('Metric Value')
plt.title('Metrics at Different Cutoff Values')
plt.legend()
plt.show()

# %%
# Plot accuracy, sensitivity, and specificity at different values of probability cutoffs
plt.figure(figsize=(8,5))
plt.plot(cutoff_df['cutoff'], cutoff_df['accuracy'], label='Accuracy')
plt.plot(cutoff_df['cutoff'], cutoff_df['sensitivity'], label='Sensitivity (Recall)')
plt.plot(cutoff_df['cutoff'], cutoff_df['specificity'], label='Specificity')
plt.xlabel('Probability Cutoff')
plt.ylabel('Metric Value')
plt.title('Metrics at Different Cutoff Values')
plt.legend()
plt.show()

# %% [markdown]
# #### **7.3.4** Create a column for final prediction based on optimal cutoff <font color="red">[1 Mark]</font>

# %%
# Create a column for final prediction based on the optimal cutoff

cutoff_df['diff'] = np.abs(cutoff_df['sensitivity'] - cutoff_df['specificity'])
optimal_cutoff = cutoff_df.loc[cutoff_df['diff'].idxmin(), 'cutoff']
print(optimal_cutoff)


output_df['final_pred'] = (output_df['predicted_prob'] >= optimal_cutoff).astype(int)
# Out:
# 0.59

# %% [markdown]
# #### **7.3.5** Calculate the accuracy <font color="red">[1 Mark]</font>

# %%
# Check the accuracy now
accuracy_opt = metrics.accuracy_score(output_df['fraud_reported_actual'], output_df['final_pred'])
print(accuracy_opt)
# Out:
# 0.9392789373814042

# %% [markdown]
# #### **7.3.6** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix once again
conf_matrix_optimized = metrics.confusion_matrix(output_df['fraud_reported_actual'], output_df['final_pred'])
print(conf_matrix_optimized)
# Out:
# [[495  32]
#  [ 32 495]]

# %% [markdown]
# #### **7.3.7** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = conf_matrix_optimized.ravel()
print(f"TP: {tp}, TN: {tn}, FP: {fp}, FN: {fn}")
# Out:
# TP: 495, TN: 495, FP: 32, FN: 32

# %% [markdown]
# #### **7.3.8** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[2 Mark]</font>

# %%
# Calculate the sensitivity

sensitivity = tp / (tp + fn)
# Calculate the specificity
specificity = tn / (tn + fp)

# Calculate Precision
precision = tp / (tp + fp)

# Calculate Recall
recall = sensitivity

# Calculate F1 Score
f1 = 2 * (precision * recall) / (precision + recall)

# %% [markdown]
# **Precision and Recall tradeoff**
#
# Check optimal cutoff value by plotting precision-recall curve, and adjust the cutoff based on precision and recall tradeoff if required.

# %%
# Import precision-recall curve function
from sklearn.metrics import precision_recall_curve

# %% [markdown]
# #### **7.3.9** Plot precision-recall curve <font color="red">[1 Mark]</font>

# %%
# Plot precision-recall curve
from sklearn.metrics import precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

y_true = output_df['fraud_reported_actual']
y_score = output_df['predicted_prob']


precision, recall, thresholds = precision_recall_curve(y_true, y_score)
avg_precision = average_precision_score(y_true, y_score)


plt.figure(figsize=(6,4))
plt.plot(recall, precision, label='Precision-Recall curve (AP = %0.2f)' % avg_precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.show()

# %% [markdown]
# ### **7.4 Build Random Forest Model** <font color = red>[12 marks]</font>
# Now that you have built a logistic regression model, let's move on to building a random forest model.

# %% [markdown]
# #### **7.4.1** Import necessary libraries

# %%
# Import necessary libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix

# %% [markdown]
# #### **7.4.2** Build the random forest model <font color="red">[1 Mark]</font>

# %%
# Build a base random forest model
rf = RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced')
rf.fit(X_train_scaled[col], y_train_resampled)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=42)

# %% [markdown]
# #### **7.4.3** Get feature importance scores and select important features <font color="red">[2 Marks]</font>

# %%
# Get feature importance scores from the trained model
importances = rf.feature_importances_
feat_imp_df = pd.DataFrame({
    'Feature': col,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

display(feat_imp_df)

# Create a DataFrame to visualise the importance scores
# Out:
#                             Feature  Importance
# 69   incident_severity_Minor Damage    0.068341
# 45            insured_hobbies_chess    0.054075
# 70     incident_severity_Total Loss    0.050625
# 12                   property_claim    0.048476
# 13                    vehicle_claim    0.047660
# ..                              ...         ...
# 121           auto_model_Highlander    0.000652
# 122              auto_model_Impreza    0.000639
# 111                  auto_model_CRV    0.000538
# 105                   auto_model_93    0.000345
# 109               auto_model_Accord    0.000228
#
# [142 rows x 2 columns]

# %%
# Select features with high importance scores
important_cols = feat_imp_df[feat_imp_df['Importance'] > feat_imp_df['Importance'].mean()]['Feature'].tolist()
print("Selected important features:", important_cols)


X_train_rf = X_train_scaled[important_cols]
# Create a new training data with only the selected features
# Out:
# Selected important features: ['incident_severity_Minor Damage', 'insured_hobbies_chess', 'incident_severity_Total Loss', 'property_claim', 'vehicle_claim', 'insured_zip', 'policy_annual_premium', 'months_as_customer', 'days_from_policy_date', 'age', 'incident_hour_of_the_day', 'auto_year', 'policy_bind_month', 'capital-gains', 'capital-loss', 'insured_hobbies_cross-fit', 'incident_dayofweek', 'witnesses', 'collision_type_others', 'incident_state_WV', 'bodily_injuries', 'umbrella_limit', 'policy_deductable', 'incident_type_Vehicle Theft', 'incident_month', 'property_damage_YES']

# %% [markdown]
# #### **7.4.4** Train the model with selected features <font color="red">[1 Mark]</font>

# %%
# Fit the model on the training data with selected features
rf_imp = RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced')
rf_imp.fit(X_train_rf, y_train_resampled)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=42)

# %% [markdown]
# #### **7.4.5** Generate predictions on the training data <font color="red">[1 Mark]</font>

# %%
# Generate predictions on training data
y_train_rf_pred = rf_imp.predict(X_train_rf)
y_train_rf_prob = rf_imp.predict_proba(X_train_rf)[:, 1]

# %% [markdown]
# #### **7.4.6** Check accuracy of the model <font color="red">[1 Mark]</font>

# %%
# Check accuracy of the model
acc_rf = accuracy_score(y_train_resampled, y_train_rf_pred)
print(acc_rf)
# Out:
# 1.0

# %% [markdown]
# #### **7.4.7** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix to visualise the performance
conf_matrix_rf = confusion_matrix(y_train_resampled, y_train_rf_pred)
print("Confusion Matrix:\n", conf_matrix_rf)
# Out:
# Confusion Matrix:
#  [[527   0]
#  [  0 527]]

# %% [markdown]
# #### **7.4.8** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = conf_matrix_rf.ravel()
print(f"TP: {tp}, TN: {tn}, FP: {fp}, FN: {fn}")
# Out:
# TP: 527, TN: 527, FP: 0, FN: 0

# %% [markdown]
# #### **7.4.9** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity = tp / (tp + fn)

# Calculate the specificity

specificity = tn / (tn + fp)
# Calculate Precision

precision = tp / (tp + fp)
# Calculate Recall
recall = sensitivity

# Calculate F1 Score
f1 = 2 * (precision * recall) / (precision + recall)

# %% [markdown]
# #### **7.4.10** Check if the model is overfitting training data using cross validation <font color = "red">[2 marks]</font>

# %%
# Use cross validation to check if the model is overfitting
cv_scores = cross_val_score(
    rf_imp, 
    X_train_rf, 
    y_train_resampled, 
    cv=5, 
    scoring='accuracy'
)
print( cv_scores)
print(
    np.mean(cv_scores))
# Out:
# [0.91943128 0.95260664 0.93364929 0.93364929 0.92380952]
# 0.9326292033401037

# %% [markdown]
# ### **7.5 Hyperparameter Tuning** <font color = red>[10 Marks]</font>
#  Enhance the performance of the random forest model by systematically exploring and selecting optimal hyperparameter values using grid search.

# %% [markdown]
# #### **7.5.1** Use grid search to find the best hyperparameter values <font color = red>[2 Marks]</font>

# %%
# Use grid search to find the best hyperparamter values

# Best Hyperparameters
from sklearn.model_selection import GridSearchCV


param_grid = {
    'n_estimators': [100, 200],             
    'max_depth': [None, 10, 20],            
    'min_samples_split': [2, 5],             
    'min_samples_leaf': [1, 2],              
    'max_features': ['auto', 'sqrt']         
}

rf_gs = RandomForestClassifier(random_state=42, class_weight='balanced')
grid_search = GridSearchCV(rf_gs, param_grid, cv=3, scoring='accuracy', n_jobs=-1, verbose=1)
grid_search.fit(X_train_rf, y_train_resampled)

print( grid_search.best_params_)
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}

# %% [markdown]
# #### **7.5.2** Build a random forest model based on hyperparameter tuning results <font color = red>[1 Mark]</font>

# %%
# Building random forest model based on results of hyperparameter tuning
rf_best = grid_search.best_estimator_
rf_best.fit(X_train_rf, y_train_resampled)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=42)

# %% [markdown]
# #### **7.5.3** Make predictions on training data <font color = red>[1 Mark]</font>

# %%
# Make predictions on training data
y_train_rf_best_pred = rf_best.predict(X_train_rf)
y_train_rf_best_prob = rf_best.predict_proba(X_train_rf)[:, 1]

# %% [markdown]
# #### **7.5.4** Check accuracy of Random Forest Model <font color = red>[1 Mark]</font>

# %%
# Check the accuracy
acc_rf_tuned = accuracy_score(y_train_resampled, y_train_rf_best_pred)
print( acc_rf_tuned)
# Out:
# 1.0

# %% [markdown]
# #### **7.5.5** Create confusion matrix <font color = red>[1 Mark]</font>

# %%
# Create the confusion matrix
conf_matrix_rf_tuned = confusion_matrix(y_train_resampled, y_train_rf_best_pred)
print(conf_matrix_rf_tuned
     )
# Out:
# [[527   0]
#  [  0 527]]

# %% [markdown]
# #### **7.5.6** Create variables for true positive, true negative, false positive and false negative <font color = red>[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = conf_matrix_rf_tuned.ravel()
print(f"TP: {tp}, TN: {tn}, FP: {fp}, FN: {fn}")
# Out:
# TP: 527, TN: 527, FP: 0, FN: 0

# %% [markdown]
# #### **7.5.7** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color = red>[3 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity = tp / (tp + fn)

# Calculate the specificity

specificity = tn / (tn + fp)
# Calculate Precision

precision = tp / (tp + fp)
# Calculate Recall

recall = sensitivity
# Calculate F1-Score
f1 = 2 * (precision * recall) / (precision + recall)

# %%
print(f"Sensitivity: {sensitivity:.3f}")
print(f"Specificity: {specificity:.3f}")
print(f"Precision: {precision:.3f}")
print(f"F1 Score: {f1:.3f}")
# Out:
# Sensitivity: 1.000
# Specificity: 1.000
# Precision: 1.000
# F1 Score: 1.000

# %% [markdown]
# ## **8. Prediction and Model Evaluation** <font color = red>[20 marks]</font>
# Use the model from the previous step to make predictions on the validation data with the optimal cutoff. Then evaluate the model's performance using metrics such as accuracy, sensitivity, specificity, precision, and recall.

# %% [markdown]
# ### **8.1 Make predictions over validation data using logistic regression model** <font color = red>[10 marks]</font>

# %% [markdown]
# #### **8.1.1** Select relevant features for validation data and add constant <font color="red">[1 Mark]</font>

# %%
# Select the relevant features for validation data
X_val_final = X_val_scaled[col]  
X_val_const = sm.add_constant(X_val_final)
# Add constant to X_validation

# %% [markdown]
# #### **8.1.2** Make predictions over validation data <font color="red">[1 Mark]</font>

# %%
X_val_const = X_val_const.astype(float)

# %%
# Make predictions on the validation data and store it in the variable 'y_validation_pred'
y_val_pred_prob = result.predict(X_val_const)

# %% [markdown]
# #### **8.1.3** Create DataFrame with actual values and predicted values for validation data <font color="red">[2 Marks]</font>

# %%
#  Create DataFrame with actual values and predicted values for validation data
output_val_df = pd.DataFrame({
    'fraud_reported_actual': y_val_bin,   
    'predicted_prob': y_val_pred_prob
})

# %% [markdown]
# #### **8.1.4** Make final prediction based on cutoff value <font color="red">[1 Mark]</font>

# %%
# Make final predictions on the validation data using the optimal cutoff
output_val_df['predicted_label'] = (output_val_df['predicted_prob'] >= optimal_cutoff).astype(int)

# %% [markdown]
# #### **8.1.5** Check the accuracy of logistic regression model on validation data <font color="red">[1 Mark]</font>

# %%
# Check the accuracy
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

acc_val = accuracy_score(output_val_df['fraud_reported_actual'], output_val_df['predicted_label'])
print(acc_val)
# Out:
# 0.76

# %% [markdown]
# #### **8.1.6** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix
conf_matrix_val = confusion_matrix(output_val_df['fraud_reported_actual'], output_val_df['predicted_label'])
print(conf_matrix_val)
# Out:
# [[190  36]
#  [ 36  38]]

# %% [markdown]
# #### **8.1.7** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = conf_matrix_val.ravel()
print(f"TP: {tp}, TN: {tn}, FP: {fp}, FN: {fn}")
# Out:
# TP: 38, TN: 190, FP: 36, FN: 36

# %% [markdown]
# #### **8.1.8** Calculate sensitivity, specificity, precision, recall and f1 score of the model <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity = tp / (tp + fn)


# Calculate the specificity
specificity = tn / (tn + fp)

# Calculate Precision
precision = tp / (tp + fp)



# Calculate Recall

recall = sensitivity

# Calculate F1 Score
f1 = 2 * (precision * recall) / (precision + recall)

# %%
 print(f"Sensitivity (Recall): {sensitivity:.3f}")
print(f"Specificity: {specificity:.3f}")
print(f"Precision: {precision:.3f}")
print(f"Recall: {recall:.3f}")
print(f"F1 Score: {f1:.3f}")
# Out:
# Sensitivity (Recall): 0.581
# Specificity: 0.898
# Precision: 0.652
# Recall: 0.581
# F1 Score: 0.614

# %% [markdown]
# ### **8.2 Make predictions over validation data using random forest model** <font color = red>[10 marks]</font>

# %% [markdown]
# #### **8.2.1** Select the important features and make predictions over validation data <font color="red">[2 Marks]</font>

# %%
# Select the relevant features for validation data
X_val_rf = X_val_scaled[important_cols]    

# Predict on validation set
y_val_rf_pred = rf_imp.predict(X_val_rf)
y_val_rf_prob = rf_imp.predict_proba(X_val_rf)[:, 1]

# %% [markdown]
# #### **8.2.2** Check accuracy of random forest model <font color="red">[1 Mark]</font>

# %%
# Check accuracy
acc_val_rf = accuracy_score(y_val_bin, y_val_rf_pred)
print( acc_val_rf)
# Out:
# 0.82

# %% [markdown]
# #### **8.2.3** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix
conf_matrix_val_rf = confusion_matrix(y_val_bin, y_val_rf_pred)
print( conf_matrix_val_rf)
# Out:
# [[203  23]
#  [ 31  43]]

# %% [markdown]
# #### **8.2.4** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = conf_matrix_val_rf.ravel()
print(f"TP: {tp}, TN: {tn}, FP: {fp}, FN: {fn}")
# Out:
# TP: 43, TN: 203, FP: 23, FN: 31

# %% [markdown]
# #### **8.2.5** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[5 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity = tp / (tp + fn)


# Calculate the specificity
specificity = tn / (tn + fp)

# Calculate Precision
precision = tp / (tp + fp)



# Calculate Recall

recall = sensitivity

# Calculate F1 Score
f1 = 2 * (precision * recall) / (precision + recall)

# %%
print(f"Sensitivity : {sensitivity:.3f}")
print(f"Specificity: {specificity:.3f}")
print(f"Precision: {precision:.3f}")
print(f"Recall: {recall:.3f}")
print(f"F1 Score: {f1:.3f}")
# Out:
# Sensitivity : 0.581
# Specificity: 0.898
# Precision: 0.652
# Recall: 0.581
# F1 Score: 0.614

# %% [markdown]
# ## **Evaluation and Conclusion**
# Write the conclusion.
